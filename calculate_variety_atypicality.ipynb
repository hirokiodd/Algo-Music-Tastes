# %%
import pandas as pd
import numpy as np

co_genre_data = pd.read_csv("../data/cogenre_network/category_stats.csv")
co_genre_data.head()
# Out:
#      category  num_nodes  num_edges  num_inter_category_edges  \
# 0         EBM          2        110                       105
# 1    Big Beat          1         67                        67
# 2      Grunge          5        136                       131
# 3  Bossa Nova          2        139                       139
# 4      Lounge          2         59                        54
#
#    average_atypicality
# 0                  8.0
# 1                  8.0
# 2                  5.8
# 3                  5.5
# 4                  5.5

# %%
atypicality = pd.read_csv("../data/cogenre_network/atypicality.csv")
atypicality.head()
# Out:
#             sub-genre  atypicality    category
# 0          a cappella            5  A Cappella
# 1      sda a cappella            3  A Cappella
# 2  college a cappella            3  A Cappella
# 3      haitian gospel            4      Gospel
# 4       naija worship            3   Christian

# %%
# Set up the genre seeds
genre_seeds = [
    "acoustic",
    "afrobeat",
    "alt-rock",
    "alternative",
    "ambient",
    "anime",
    "black-metal",
    "bluegrass",
    "blues",
    "bossanova",
    "brazil",
    "breakbeat",
    "british",
    "cantopop",
    "chicago-house",
    "children",
    "chill",
    "classical",
    "club",
    "comedy",
    "country",
    "dance",
    "dancehall",
    "death-metal",
    "deep-house",
    "detroit-techno",
    "disco",
    "disney",
    "drum-and-bass",
    "dub",
    "dubstep",
    "edm",
    "electro",
    "electronic",
    "emo",
    "folk",
    "forro",
    "french",
    "funk",
    "garage",
    "german",
    "gospel",
    "goth",
    "grindcore",
    "groove",
    "grunge",
    "guitar",
    "happy",
    "hard-rock",
    "hardcore",
    "hardstyle",
    "heavy-metal",
    "hip-hop",
    "holidays",
    "honky-tonk",
    "house",
    "idm",
    "indian",
    "indie",
    "indie-pop",
    "industrial",
    "iranian",
    "j-dance",
    "j-idol",
    "j-pop",
    "j-rock",
    "jazz",
    "k-pop",
    "kids",
    "latin",
    "latino",
    "malay",
    "mandopop",
    "metal",
    "metal-misc",
    "metalcore",
    "minimal-techno",
    "movies",
    "mpb",
    "new-age",
    "new-release",
    "opera",
    "pagode",
    "party",
    "philippines-opm",
    "piano",
    "pop",
    "pop-film",
    "post-dubstep",
    "power-pop",
    "progressive-house",
    "psych-rock",
    "punk",
    "punk-rock",
    "r-n-b",
    "rainy-day",
    "reggae",
    "reggaeton",
    "road-trip",
    "rock",
    "rock-n-roll",
    "rockabilly",
    "romance",
    "sad",
    "salsa",
    "samba",
    "sertanejo",
    "show-tunes",
    "singer-songwriter",
    "ska",
    "sleep",
    "songwriter",
    "soul",
    "soundtracks",
    "spanish",
    "study",
    "summer",
    "swedish",
    "synth-pop",
    "tango",
    "techno",
    "trance",
    "trip-hop",
    "turkish",
    "work-out",
    "world-music",
]

# %%
# Count the number of genre seeds
len(genre_seeds)
# Out:
# 126

# %%
# Check atypicality of each genre seed based on the atypicality dataframe
genre_seed_atypicality = atypicality[atypicality["sub-genre"].isin(genre_seeds)]
genre_seed_atypicality.sort_values(by="atypicality", ascending=False)
# Out:
#               sub-genre  atypicality           category
# 167              j-rock           17               Rock
# 360               anime           16         Soundtrack
# 44              ambient           15            Ambient
# 225          industrial           14         Industrial
# 149                folk           14               Folk
# 163               j-pop           14                Pop
# 343           metalcore           12              Metal
# 238                rock           12               Rock
# 22                  edm           11         Electronic
# 139               blues           10              Blues
# 146   singer-songwriter           10  Singer-Songwriter
# 912            afrobeat            9           Afrobeat
# 757               house            9              House
# 296                punk            9               Punk
# 291                 emo            9                Emo
# 438           bluegrass            9          Bluegrass
# ...

# %%
genre_seed_atypicality.count()
# Out:
# sub-genre      52
# atypicality    52
# category       52
# dtype: int64
